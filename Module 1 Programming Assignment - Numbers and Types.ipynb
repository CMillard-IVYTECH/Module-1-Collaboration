# %%
# Number of seconds in a minute times number of minutes in an hour
60 * 60
# Out:
# 3600

# %%
seconds_per_hour = 60 * 60
seconds_per_hour
# Out:
# 3600

# %%
# A day has 24 hours
24 * seconds_per_hour
# Out:
# 86400

# %%
seconds_per_day = 24 * seconds_per_hour
seconds_per_day
# Out:
# 86400

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %%
# 3.1: There are 3600 seconds in one hour.
# 3.2: The variable seconds_per_hour now stores the value 3600.
# 3.3: There are 86,400 seconds in one day.
# 3.4:
